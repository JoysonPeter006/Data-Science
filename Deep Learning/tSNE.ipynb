# %%
import pandas as pd
import seaborn as sns
from sklearn.manifold import TSNE
from sklearn.datasets import load_iris
from numpy import reshape

# %%
iris = load_iris()
x = iris.data
y = iris.target

# %%
tsne = TSNE(n_components = 2, verbose = 2, random_state = 23)
z = tsne.fit_transform(x)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 150 samples in 0.000s...
# [t-SNE] Computed neighbors for 150 samples in 0.295s...
# [t-SNE] Computed conditional probabilities for sample 150 / 150
# [t-SNE] Mean sigma: 0.509910
# [t-SNE] Computed conditional probabilities in 0.031s
# [t-SNE] Iteration 50: error = 51.5014954, gradient norm = 0.5574401 (50 iterations in 0.125s)
# [t-SNE] Iteration 100: error = 50.9585876, gradient norm = 0.5665053 (50 iterations in 0.036s)
# [t-SNE] Iteration 150: error = 49.7450256, gradient norm = 0.5926151 (50 iterations in 0.033s)
# [t-SNE] Iteration 200: error = 51.4757500, gradient norm = 0.5129117 (50 iterations in 0.027s)
# [t-SNE] Iteration 250: error = 51.6617203, gradient norm = 0.4884909 (50 iterations in 0.016s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 51.661720
# [t-SNE] Iteration 300: error = 0.1752226, gradient norm = 0.0080622 (50 iterations in 0.031s)
# [t-SNE] Iteration 350: error = 0.1240429, gradient norm = 0.0005108 (50 iterations in 0.031s)
# [t-SNE] Iteration 400: error = 0.1224856, gradient norm = 0.0003465 (50 iterations in 0.031s)
# [t-SNE] Iteration 450: error = 0.1216668, gradient norm = 0.0003194 (50 iterations in 0.016s)
# [t-SNE] Iteration 500: error = 0.1209982, gradient norm = 0.0002394 (50 iterations in 0.043s)
# [t-SNE] Iteration 550: error = 0.1200856, gradient norm = 0.0002565 (50 iterations in 0.029s)
# [t-SNE] Iteration 600: error = 0.1202690, gradient norm = 0.0001050 (50 iterations in 0.020s)
# [t-SNE] Iteration 650: error = 0.1202514, gradient norm = 0.0002697 (50 iterations in 0.038s)
# [t-SNE] Iteration 700: error = 0.1198095, gradient norm = 0.0001549 (50 iterations in 0.028s)
# [t-SNE] Iteration 750: error = 0.1194824, gradient norm = 0.0000963 (50 iterations in 0.019s)
# [t-SNE] Iteration 800: error = 0.1193766, gradient norm = 0.0001463 (50 iterations in 0.031s)
# [t-SNE] Iteration 850: error = 0.1191198, gradient norm = 0.0001871 (50 iterations in 0.037s)
# [t-SNE] Iteration 900: error = 0.1189035, gradient norm = 0.0002412 (50 iterations in 0.029s)
# [t-SNE] Iteration 950: error = 0.1191418, gradient norm = 0.0001762 (50 iterations in 0.021s)
# [t-SNE] Iteration 1000: error = 0.1192021, gradient norm = 0.0001529 (50 iterations in 0.038s)
# [t-SNE] KL divergence after 1000 iterations: 0.119202

# %%
df = pd.DataFrame()
df['y'] = y
df['comp-1'] = z[:, 0]
df['comp-2'] = z[:, 1]

# %%
sns.scatterplot(x = 'comp-1', y = 'comp-2', hue = df.y.tolist(), palette = sns.color_palette('hls', 3), data = df).set(title = 'Iris data tSNE projection')
# Out:
# [Text(0.5, 1.0, 'Iris')]
